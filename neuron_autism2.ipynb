# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

file_names = {'WTM3':'2024_11_12_0003.abf',
              'Bckdk':'2024_11_27_0017.abf',
              'USP7': '2024_12_02_0009.abf'}
sheet_names = {'WTM3': 'WT M3 C3 003.abf',
               'Bckdk': 'Bckdk KO M11 C3 017.abf ',
               'USP7': 'Usp7 Het M13 009.abf'}

consider = 'WTM3'
data = pd.read_excel('AP_traces.xlsx', sheet_name=sheet_names[consider],
                     usecols='B:O',  header=0, skiprows=[1])

# %%
from threshold_crossing import count_spikes
def show_rawdata(ax, currs=['15 pA', '25 pA', '35 pA']):
    for cc in currs:
        ax.plot(data['Time (ms)'] / 1000, 
                data[cc], 
                label=cc)
    ax.set_xlim(-0.1, 1.5)
    ax.set_ylim(-80, 50)
    ax.legend()
    return ax

def show_ficurve(ax, currs=['10 pA', '15 pA', '20 pA', '25 pA', '30 pA', '35 pA']):
    ffs = []
    cur_vals = []
    for cc in currs:
        cur_vals.append(int(cc.strip('pA').strip()))
        ffs.append(count_spikes(np.array(data[cc])))
    print(ffs)
    ax.plot(cur_vals, ffs, label='Recording', c='k', marker='o')
    ax.set_ylim(-1, 30)
    ax.set_xlim(0, 50)
    return ax

# %%
import ipywidgets as widgets
import numpy as np
from IPython.display import display, clear_output
from widgets_aut import *
# Out:
# <style>div.output_scroll { height: 44em; }</style>

# %%
from neuron472299294_250811 import Neuron472299294
from test_autism4 import *
from neuron import h
h.celsius = 34.0
cell = Neuron472299294(name='neuron', shrink_by=0.7)
# Out:
# Shrunk by 0.7
# Using file Rorb-IRES2-Cre-D_Ai14_IVSCC_-168052.03.02.01_397999191_m_shrinked_0.7.swc
# Shrunk axon by 0.5
# NEURON: unable to open font "*helvetica-medium-r-normal*--14*", using "fixed"

# %%
def get_passive_range(cm, g_pas, ra):
    min_cm, min_g_pas, min_ra = cm[0], g_pas[0], ra[0]
    max_cm, max_g_pas, max_ra = cm[1], g_pas[1], ra[1]
    # cell.update_factors({'cm': cm, 'g_pas': g_pas, 'ra': ra})
r = widgets.interact(get_passive_range, cm=pick_cm_range, 
                     g_pas=pick_gpas_range, ra=pick_Ra_range)
# Out:
# interactive(children=(FloatRangeSlider(value=(0.5, 1.5), continuous_update=False, description='cm:', layout=La…

# %%
cell, results, clamp = demo([15, 25, 35], {'cm': pick_cm_range.value[0], 
                                           'g_pas': pick_gpas_range.value[0], 
                                           'ra': pick_Ra_range.value[0]})
# Out:
# Shrunk by 0.7
# Using file Rorb-IRES2-Cre-D_Ai14_IVSCC_-168052.03.02.01_397999191_m_shrinked_0.7.swc
# Shrunk axon by 0.5
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 cell, results, clamp = demo([15, 25, 35], {'cm': pick_cm_range.value[0],
#       2                                            'g_pas': pick_gpas_range.value[0],
#       3                                            'ra': pick_Ra_range.value[0]})
#
# File ~/Gaia/Autism/Allen_L23/L23Pyr/test_autism4.py:46, in demo(iapp, update_dict)
#      44 cell = Neuron472299294(name='neuron', shrink_by=0.7)
#      45 #update values
# ---> 46 cell.update_factors(update_dict)
#      48 # clamp
#      49 ic = h.IClamp(0.5, sec=cell.soma[0])
#
# File ~/Gaia/Autism/Allen_L23/L23Pyr/neuron472299294_250811.py:51, in Neuron472299294.update_factors(self, f_dict)
#      49 def update_factors(self, f_dict):
#      50     n_dict = {}
# ---> 51     n_dict['e_pas'] =  f_dict.pop('e_pas')
#      52     n_dict['ena'] =  f_dict.pop('ena')
#      53     n_dict['ek'] =  f_dict.pop('ek')
#
# KeyError: 'e_pas'

# %%
cell, results, clamp = demo([15, 25, 35], {'cm': 1, 
                                           'g_pas': 1, 
                                           'ra': 1})
# Out:
# Shrunk by 0.7
# Using file Rorb-IRES2-Cre-D_Ai14_IVSCC_-168052.03.02.01_397999191_m_shrinked_0.7.swc
# Shrunk axon by 0.5

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 12 ,6
fig, ax = plt.subplots(1,3)
ax[0] = show_rawdata(ax[0])
ax[2] = show_ficurve(ax[2])
ax[1] = make_plots(ax[1], results)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       3 fig, ax = plt.subplots(1,3)
#       4 ax[0] = show_rawdata(ax[0])
# ----> 5 ax[2] = show_ficurve(ax[2])
#       6 ax[1] = make_plots(ax[1], results)
#
# TypeError: show_ficurve() missing 1 required positional argument: 'results'

# %%
def get_active(Na_T, Na_P, K_P, K_T, Kv_3_1, SK, HVA, LVA, Im, Ih):
    cell.update_factors({'cm': pick_cm.value, 
                         'g_pas': pick_gpas.value, 
                         'ra': pick_Ra.value,
                         'gbar_NaTs': Na_T, 
                         'gbar_Nap': Na_P,
                         'gbar_K_P': K_P, 
                         'gbar_K_T': K_T,
                         'gbar_Kv_3_1': Kv_3_1, 
                         'gbar_SK': SK,
                         'gbar_Ca_HVA': HVA,
                         'gbar_Ca_LVA': LVA,
                         'gbar_Im': Im,
                         'gbar_Ih':Ih})
r2 = widgets.interact(get_active,
                      cm=pick_cm, g_pas=pick_gpas, ra=pick_Ra,
                      Na_T=pick_gbar_NaTs, 
                      Na_P=pick_gbar_Nap,
                      K_P=pick_gbar_K_P, 
                      K_T=pick_gbar_K_T,
                      Kv_3_1=pick_gbar_Kv_3_1, 
                      SK=pick_gbar_SK,
                      HVA=pick_gbar_Ca_HVA,
                      LVA=pick_gbar_Ca_LVA,
                      Im=pick_gbar_Im,
                      Ih=pick_gbar_Ih)

# %%
cell, results, clamp = demo([15, 25, 35], {'cm': pick_cm.value, 
                                           'g_pas': 0.35, # pick_gpas.value, 
                                           'ra': pick_Ra.value,
                                           'gbar_NaTs': pick_gbar_NaTs.value, 
                                           'gbar_Nap': pick_gbar_Nap.value, 
                                           'gbar_K_P': pick_gbar_K_P.value, 
                                           'gbar_K_T':pick_gbar_K_T.value,
                                           'gbar_Kv_3_1':pick_gbar_Kv_3_1.value, 
                                           'gbar_SK':pick_gbar_SK.value,
                                           'gbar_Ca_HVA':pick_gbar_Ca_HVA.value,
                                           'gbar_Ca_LVA':pick_gbar_Ca_LVA.value,
                                           'gbar_Im':pick_gbar_Im.value,
                                           'gbar_Ih':pick_gbar_Ih.value})

# %%
consider = 'USP7'
data = pd.read_excel('AP_traces.xlsx', sheet_name=sheet_names[consider],
                     usecols='B:O',  header=0, skiprows=[1])

# %%
rcParams['figure.figsize'] = 11 ,6
fig, ax = plt.subplots(1,2)
ax[0] = show_rawdata(ax[0])
ax[1] = make_plots(ax[1], results)

# %%
rcParams['figure.figsize'] = 11 ,6
fig, ax = plt.subplots(1,2)
ax[0] = show_rawdata(ax[0])
ax[1] = make_plots(ax[1], results)
